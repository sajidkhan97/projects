# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Modules are imported.')
# Out:
# Modules are imported.

# %%
corona_dataset = pd.read_csv(r"C:\Users\suhail\Desktop\covid\RAW_global_confirmed_cases.csv")
corona_dataset.head(5)
# Out:
#   Country/Region Province/State       Lat       Long  1/22/20  1/23/20  \
# 0    Afghanistan            NaN  33.93911  67.709953        0        0
# 1        Albania            NaN  41.15330  20.168300        0        0
# 2        Algeria            NaN  28.03390   1.659600        0        0
# 3        Andorra            NaN  42.50630   1.521800        0        0
# 4         Angola            NaN -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  12/2/20  12/3/20  12/4/20  \
# 0        0        0        0        0  ...    46718    46837    46837
# 1        0        0        0        0  ...    39719    40501    41302
# 2        0        0        0        0  ...    85084    85927    86730
# 3        0        0        0        0  ...     6842     6904     6955
# 4        0        0        0        0  ...    15319    15361    15493
#
#    12/5/20  12/6/20  12/7/20  12/8/20  12/9/20  12/10/20  12/11/20
# ...

# %%
corona_dataset.shape
# Out:
# (271, 329)

# %%
corona_dataset.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dataset.head(10)
# Out:
#         Country/Region                Province/State  1/22/20  1/23/20  \
# 0          Afghanistan                           NaN        0        0
# 1              Albania                           NaN        0        0
# 2              Algeria                           NaN        0        0
# 3              Andorra                           NaN        0        0
# 4               Angola                           NaN        0        0
# 5  Antigua and Barbuda                           NaN        0        0
# 6            Argentina                           NaN        0        0
# 7              Armenia                           NaN        0        0
# 8            Australia  Australian Capital Territory        0        0
# 9            Australia               New South Wales        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  12/2/20  \
# 0        0        0        0        0        0        0  ...    46718
# ...

# %%
 corona_dataset_aggregated = corona_dataset.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(100)
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
# ...                 ...      ...      ...      ...      ...      ...      ...
# Laos                  0        0        0        0        0        0        0
# Latvia                0        0        0        0        0        0        0
# Lebanon               0        0        0        0        0        0        0
# Lesotho               0        0        0        0        0        0        0
# Liberia               0        0        0        0        0        0        0
#
# ...

# %%
corona_dataset_aggregated.describe()
# Out:
#           1/22/20     1/23/20     1/24/20      1/25/20      1/26/20  \
# count  191.000000  191.000000  191.000000   191.000000   191.000000
# mean     2.905759    3.424084    4.926702     7.507853    11.089005
# std     39.649936   46.522810   66.563265   101.726458   150.128567
# min      0.000000    0.000000    0.000000     0.000000     0.000000
# 25%      0.000000    0.000000    0.000000     0.000000     0.000000
# 50%      0.000000    0.000000    0.000000     0.000000     0.000000
# 75%      0.000000    0.000000    0.000000     0.000000     0.000000
# max    548.000000  643.000000  920.000000  1406.000000  2075.000000
#
#            1/27/20      1/28/20      1/29/20      1/30/20      1/31/20  ...  \
# count   191.000000   191.000000   191.000000   191.000000   191.000000  ...
# mean     15.324607    29.204188    32.287958    43.115183    51.973822  ...
# std     208.156114   398.593996   440.412565   589.029503   709.204702  ...
# ...

# %%
 corona_dataset_aggregated.shape
# Out:
# (191, 325)

# %%
corona_dataset_aggregated.loc['Afghanistan'].plot()
corona_dataset_aggregated.loc['Lesotho'].plot()
corona_dataset_aggregated.loc['Laos'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['India'].plot()
#good measure

# %%
corona_dataset_aggregated.loc['India'].diff().plot()
#first derivative of the curve

# %%
 corona_dataset_aggregated.loc['India'].diff().max()
# Out:
# 97894.0

# %%
 corona_dataset_aggregated.loc['India'].diff().min()
# Out:
# 0.0

# %%
corona_dataset_aggregated.loc['Spain'].diff().max()
# Out:
# 55019.0

# %%
corona_dataset_aggregated.loc['Iran'].diff().max()
# Out:
# 14051.0

# %%
corona_dataset_aggregated.loc['Turkey'].diff().max()
# Out:
# 824907.0

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates
print(max_infection_rates)
# Out:
# [915.0, 873.0, 1133.0, 299.0, 355.0, 39.0, 18326.0, 2476.0, 716.0, 9586.0, 4426.0, 310.0, 841.0, 4019.0, 12.0, 1967.0, 23921.0, 1382.0, 139.0, 29.0, 2036.0, 1953.0, 1328.0, 69074.0, 26.0, 4828.0, 193.0, 2158.0, 78.0, 159.0, 31.0, 2324.0, 7895.0, 216.0, 83.0, 13990.0, 15136.0, 13056.0, 44.0, 649.0, 414.0, 2877.0, 430.0, 4620.0, 124.0, 419.0, 15731.0, 3132.0, 99.0, 280.0, 8.0, 2147.0, 11536.0, 1774.0, 885.0, 1750.0, 38.0, 561.0, 147.0, 1829.0, 5.0, 840.0, 125414.0, 570.0, 248.0, 5450.0, 32734.0, 1513.0, 3316.0, 6.0, 4233.0, 278.0, 156.0, 133.0, 332.0, 7.0, 1324.0, 6819.0, 106.0, 97894.0, 8369.0, 14051.0, 5055.0, 1515.0, 9078.0, 40902.0, 244.0, 2977.0, 7933.0, 18757.0, 1554.0, 950.0, 2220.0, 1073.0, 11505.0, 14.0, 930.0, 2817.0, 98.0, 68.0, 1639.0, 49.0, 4551.0, 1967.0, 7.0, 614.0, 257.0, 2234.0, 215.0, 155.0, 218.0, 3.0, 233.0, 41.0, 28115.0, 1766.0, 29.0, 56.0, 874.0, 6195.0, 305.0, 324.0, 5743.0, 11172.0, 89.0, 480.0, 93.0, 796.0, 1402.0, 1680.0, 2685.0, 12073.0, 2447.0, 73.0, 1217.0
# ...

# %%
corona_dataset_aggregated.head(100)
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
# ...                 ...      ...      ...      ...      ...      ...      ...
# Laos                  0        0        0        0        0        0        0
# Latvia                0        0        0        0        0        0        0
# Lebanon               0        0        0        0        0        0        0
# Lesotho               0        0        0        0        0        0        0
# Liberia               0        0        0        0        0        0        0
#
# ...

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])

# %%
corona_data.head(100)
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                      873.0
# Algeria                     1133.0
# Andorra                      299.0
# Angola                       355.0
# ...                            ...
# Laos                          14.0
# Latvia                       930.0
# Lebanon                     2817.0
# Lesotho                       98.0
# Liberia                       68.0
#
# [100 rows x 1 columns]

# %%
world_happiness_report = pd.read_csv(r"C:\Users\suhail\Desktop\whr\2020.csv")
world_happiness_report.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
world_happiness_report.shape
# Out:
# (153, 20)

# %%
world_happiness_report.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
columns_to_dropped = ['Standard error of ladder score','Ladder score','upperwhisker','lowerwhisker']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)

# %%
world_happiness_report.head()
# Out:
#   Country name Regional indicator  Logged GDP per capita  Social support  \
# 0      Finland     Western Europe              10.639267        0.954330
# 1      Denmark     Western Europe              10.774001        0.955991
# 2  Switzerland     Western Europe              10.979933        0.942847
# 3      Iceland     Western Europe              10.772559        0.974670
# 4       Norway     Western Europe              11.087804        0.952487
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                71.900825                      0.949172   -0.059482
# 1                72.402504                      0.951444    0.066202
# 2                74.102448                      0.921337    0.105911
# 3                73.000000                      0.948892    0.246944
# 4                73.200783                      0.955750    0.134533
#
#    Perceptions of corruption  Ladder score in Dystopia  \
# ...

# %%
world_happiness_report.set_index(['Country name'],inplace=True)
world_happiness_report.head()
# Out:
#              Regional indicator  Logged GDP per capita  Social support  \
# Country name
# Finland          Western Europe              10.639267        0.954330
# Denmark          Western Europe              10.774001        0.955991
# Switzerland      Western Europe              10.979933        0.942847
# Iceland          Western Europe              10.772559        0.974670
# Norway           Western Europe              11.087804        0.952487
#
#               Healthy life expectancy  Freedom to make life choices  \
# Country name
# Finland                     71.900825                      0.949172
# Denmark                     72.402504                      0.951444
# Switzerland                 74.102448                      0.921337
# Iceland                     73.000000                      0.948892
# Norway                      73.200783                      0.955750
#
#               Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
corona_data.head()
# Out:
#                 max infection rate
# Country/Region
# Afghanistan                  915.0
# Albania                      873.0
# Algeria                     1133.0
# Andorra                      299.0
# Angola                       355.0

# %%
world_happiness_report.head()
# Out:
#              Regional indicator  Logged GDP per capita  Social support  \
# Country name
# Finland          Western Europe              10.639267        0.954330
# Denmark          Western Europe              10.774001        0.955991
# Switzerland      Western Europe              10.979933        0.942847
# Iceland          Western Europe              10.772559        0.974670
# Norway           Western Europe              11.087804        0.952487
#
#               Healthy life expectancy  Freedom to make life choices  \
# Country name
# Finland                     71.900825                      0.949172
# Denmark                     72.402504                      0.951444
# Switzerland                 74.102448                      0.921337
# Iceland                     73.000000                      0.948892
# Norway                      73.200783                      0.955750
#
#               Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#              Regional indicator  Logged GDP per capita  Social support  \
# Country name
# Finland          Western Europe              10.639267        0.954330
# Denmark          Western Europe              10.774001        0.955991
# Switzerland      Western Europe              10.979933        0.942847
# Iceland          Western Europe              10.772559        0.974670
# Norway           Western Europe              11.087804        0.952487
#
#               Healthy life expectancy  Freedom to make life choices  \
# Country name
# Finland                     71.900825                      0.949172
# Denmark                     72.402504                      0.951444
# Switzerland                 74.102448                      0.921337
# Iceland                     73.000000                      0.948892
# Norway                      73.200783                      0.955750
#
#               Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
data.corr()
# Out:
#                                             Logged GDP per capita  \
# Logged GDP per capita                                1.000000e+00
# Social support                                       7.818136e-01
# Healthy life expectancy                              8.484686e-01
# Freedom to make life choices                         4.190186e-01
# Generosity                                          -1.183994e-01
# Perceptions of corruption                           -3.347291e-01
# Ladder score in Dystopia                             1.434726e-15
# Explained by: Log GDP per capita                     1.000000e+00
# Explained by: Social support                         7.818136e-01
# Explained by: Healthy life expectancy                8.484686e-01
# Explained by: Freedom to make life choices           4.190187e-01
# Explained by: Generosity                            -1.183994e-01
# Explained by: Perceptions of corruption              3.347291e-01
# ...

# %%
data.head()
# Out:
#              Regional indicator  Logged GDP per capita  Social support  \
# Country name
# Finland          Western Europe              10.639267        0.954330
# Denmark          Western Europe              10.774001        0.955991
# Switzerland      Western Europe              10.979933        0.942847
# Iceland          Western Europe              10.772559        0.974670
# Norway           Western Europe              11.087804        0.952487
#
#               Healthy life expectancy  Freedom to make life choices  \
# Country name
# Finland                     71.900825                      0.949172
# Denmark                     72.402504                      0.951444
# Switzerland                 74.102448                      0.921337
# Iceland                     73.000000                      0.948892
# Norway                      73.200783                      0.955750
#
#               Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %% [markdown]
# # comparisions with different plotting

# %%
x = data['Explained by: Log GDP per capita'] 
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
x = data['Healthy life expectancy'] 
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
 x = data['Freedom to make life choices'] 
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
